# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
preprocessed = np.load("../../centered_digits.npy")
raw = np.load("../../train_x_npy.npy")
labels = np.loadtxt("../../train_y.csv", delimiter=",")
filtered = ((raw > 250) + 0) * 250

# %%
plt.imshow(raw[0], cmap="gray")
plt.show()
plt.imshow(filtered[0], cmap="gray")
plt.show()
plt.imshow(preprocessed[0], cmap="gray")
plt.show()

# %%
for i in range(500,600):
    plt.imshow(raw[i], cmap="gray")
    plt.show()
    plt.imshow(preprocessed[i], cmap="gray")
    plt.show()
    print(labels[i])
# Out:
# 5.0
# 9.0
# 0.0
# 9.0
# 6.0
# 3.0
# 5.0
# 3.0
# 4.0
# 7.0
# 1.0
# 7.0
# 7.0
# 0.0
# 4.0
# 6.0
# 3.0
# 4.0
# 2.0
# 0.0
# 3.0
# 0.0
# 7.0
# 9.0
# 3.0
# 1.0
# 2.0
# 0.0
# 2.0
# 2.0
# 0.0
# 7.0
# 4.0
# 3.0
# 6.0
# 2.0
# 9.0
# 1.0
# 3.0
# 8.0
# 1.0
# 7.0
# 4.0
# 7.0
# 1.0
# 0.0
# 1.0
# 9.0
# 8.0
# 1.0
# 7.0
# 0.0
# 3.0
# 0.0
# 5.0
# 5.0
# 0.0
# 5.0
# 6.0
# 8.0
# 3.0
# 3.0
# 7.0
# 9.0
# 8.0
# 5.0
# 4.0
# 9.0
# 4.0
# 8.0
# 6.0
# 5.0
# 0.0
# 1.0
# 6.0
# 8.0
# 3.0
# 9.0
# 7.0
# 4.0
# 0.0
# 9.0
# 8.0
# 0.0
# 2.0
# 3.0
# 6.0
# 7.0
# 3.0
# 2.0
# 7.0
# 6.0
# 8.0
# 4.0
# 0.0
# 6.0
# 0.0
# 8.0
# 1.0
# 2.0
